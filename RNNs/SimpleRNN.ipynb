# %%
try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.

# %%
# make the original data
series = np.sin(0.1*np.arange(200)) + np.random.randn(200)*0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
D = 1
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1) # Now the data should be N x T x D
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (190, 10, 1) Y.shape (190,)

# %%
### try autoregressive RNN model
i = Input(shape=(T, 1))
x = SimpleRNN(5, activation='relu')(i)
x = Dense(1)(x)
model = Model(i, x)
model.compile(
  loss='mse',
  optimizer=Adam(lr=0.1),
)

# train the RNN
r = model.fit(
  X[:-N//2], Y[:-N//2],
  epochs=80,
  validation_data=(X[-N//2:], Y[-N//2:]),
)
# Out:
# Train on 95 samples, validate on 95 samples
# Epoch 1/80
# 95/95 [==============================] - 2s 25ms/sample - loss: 0.6221 - val_loss: 0.3451
# Epoch 2/80
# 95/95 [==============================] - 0s 668us/sample - loss: 0.2578 - val_loss: 0.0529
# Epoch 3/80
# 95/95 [==============================] - 0s 598us/sample - loss: 0.0849 - val_loss: 0.1561
# Epoch 4/80
# 95/95 [==============================] - 0s 580us/sample - loss: 0.1343 - val_loss: 0.0512
# Epoch 5/80
# 95/95 [==============================] - 0s 537us/sample - loss: 0.0499 - val_loss: 0.0351
# Epoch 6/80
# 95/95 [==============================] - 0s 662us/sample - loss: 0.0606 - val_loss: 0.0552
# Epoch 7/80
# 95/95 [==============================] - 0s 556us/sample - loss: 0.0566 - val_loss: 0.0254
# Epoch 8/80
# 95/95 [==============================] - 0s 524us/sample - loss: 0.0309 - val_loss: 0.0369
# Epoch 9/80
# 95/95 [==============================] - 0s 583us/sample - loss: 0.0447 - val_loss: 0.0422
# Epoch 10/80
# 95/95 [==============================] - 0s 595us/sample - loss: 0.0364 - val_loss: 0.0247
# Epoch 11/80
# 95/95 [==============================] - 0s 572us/sample - loss: 0.0287 - val_loss: 0.0270
# Epoch 12/80
# 95/95 [==============================] - 0s 594us/sample - loss: 0.0342 - val_loss: 0.0260
# Epoch 13/80
# 95/95 [==============================] - 0s 532us/sample - loss: 0.0268 - val_loss: 0.0253
# Epoch 14/80
# 95/95 [==============================] - 0s 592us/sample - loss: 0.0292 - val_loss: 0.0317
# Epoch 15/80
# 95/95 [==============================] - 0s 549us/sample - loss: 0.0294 - val_loss: 0.0259
# Epoch 16/80
# 95/95 [==============================] - 0s 661us/sample - loss: 0.0248 - val_loss: 0.0244
# Epoch 17/80
# 95/95 [==============================] - 0s 720us/sample - loss: 0.0268 - val_loss: 0.0236
# Epoch 18/80
# 95/95 [==============================] - 0s 819us/sample - loss: 0.0258 - val_loss: 0.0233
# Epoch 19/80
# 95/95 [==============================] - 0s 707us/sample - loss: 0.0259 - val_loss: 0.0266
# Epoch 20/80
# 95/95 [==============================] - 0s 535us/sample - loss: 0.0256 - val_loss: 0.0242
# Epoch 21/80
# 95/95 [==============================] - 0s 564us/sample - loss: 0.0248 - val_loss: 0.0244
# Epoch 22/80
# 95/95 [==============================] - 0s 650us/sample - loss: 0.0226 - val_loss: 0.0233
# Epoch 56/80
# 95/95 [==============================] - 0s 594us/sample - loss: 0.0230 - val_loss: 0.0224
# Epoch 57/80
# 95/95 [==============================] - 0s 634us/sample - loss: 0.0229 - val_loss: 0.0232
# Epoch 58/80
# 95/95 [==============================] - 0s 614us/sample - loss: 0.0230 - val_loss: 0.0235
# Epoch 59/80
# 95/95 [==============================] - 0s 570us/sample - loss: 0.0226 - val_loss: 0.0228
# Epoch 60/80
# 95/95 [==============================] - 0s 586us/sample - loss: 0.0237 - val_loss: 0.0224
# Epoch 61/80
# 95/95 [==============================] - 0s 513us/sample - loss: 0.0224 - val_loss: 0.0241
# Epoch 62/80
# 95/95 [==============================] - 0s 571us/sample - loss: 0.0232 - val_loss: 0.0221
# Epoch 63/80
# 95/95 [==============================] - 0s 624us/sample - loss: 0.0224 - val_loss: 0.0227
# Epoch 64/80
# 95/95 [==============================] - 0s 680us/sample - loss: 0.0227 - val_loss: 0.0233
# Epoch 65/80
# 95/95 [==============================] - 0s 755us/sample - loss: 0.0227 - val_loss: 0.0232
# Epoch 66/80
# 95/95 [==============================] - 0s 683us/sample - loss: 0.0234 - val_loss: 0.0234
# Epoch 67/80
# 95/95 [==============================] - 0s 598us/sample - loss: 0.0227 - val_loss: 0.0238
# Epoch 68/80
# 95/95 [==============================] - 0s 775us/sample - loss: 0.0231 - val_loss: 0.0235
# Epoch 69/80
# 95/95 [==============================] - 0s 869us/sample - loss: 0.0238 - val_loss: 0.0224
# Epoch 70/80
# 95/95 [==============================] - 0s 646us/sample - loss: 0.0223 - val_loss: 0.0227
# Epoch 71/80
# 95/95 [==============================] - 0s 726us/sample - loss: 0.0231 - val_loss: 0.0229
# Epoch 72/80
# 95/95 [==============================] - 0s 868us/sample - loss: 0.0229 - val_loss: 0.0240
# Epoch 73/80
# 95/95 [==============================] - 0s 652us/sample - loss: 0.0243 - val_loss: 0.0228
# Epoch 74/80
# 95/95 [==============================] - 0s 691us/sample - loss: 0.0228 - val_loss: 0.0253
# Epoch 75/80
# 95/95 [==============================] - 0s 725us/sample - loss: 0.0233 - val_loss: 0.0241
# Epoch 76/80
# 95/95 [==============================] - 0s 722us/sample - loss: 0.0234 - val_loss: 0.0231
# Epoch 77/80
# 95/95 [==============================] - 0s 631us/sample - loss: 0.0230 - val_loss: 0.0238
# Epoch 78/80
# 95/95 [==============================] - 0s 691us/sample - loss: 0.0243 - val_loss: 0.0239
# Epoch 79/80
# 95/95 [==============================] - 0s 719us/sample - loss: 0.0231 - val_loss: 0.0251
# Epoch 80/80
# 95/95 [==============================] - 0s 699us/sample - loss: 0.0258 - val_loss: 0.0240

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets

validation_target = Y[-N//2:]
validation_predictions = []

# index of first validation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1, 1))[0,0] # 1x1 array -> scalar
  i += 1
  
  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# last train input
last_x = X[-N//2] # 1-D array of length T

while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, -1, 1))[0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p)
  
  # make the new input
  last_x = np.roll(last_x, -1)
  last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
