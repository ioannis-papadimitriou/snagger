# %%
try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.

# %%
# make the original data
series = np.sin(0.1*np.arange(200)) + np.random.randn(200)*0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T)
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (190, 10) Y.shape (190,)

# %%
### try autoregressive linear model
i = Input(shape=(T,))
x = Dense(1)(i)
model = Model(i, x)
model.compile(
  loss='mse',
  optimizer=Adam(lr=0.1),
)

# train the RNN
r = model.fit(
  X[:-N//2], Y[:-N//2],
  epochs=80,
  validation_data=(X[-N//2:], Y[-N//2:]),
)
# Out:
# Train on 95 samples, validate on 95 samples
# Epoch 1/80
# 95/95 [==============================] - 1s 12ms/sample - loss: 0.2543 - val_loss: 0.2572
# Epoch 2/80
# 95/95 [==============================] - 0s 274us/sample - loss: 0.1828 - val_loss: 0.0488
# Epoch 3/80
# 95/95 [==============================] - 0s 228us/sample - loss: 0.1208 - val_loss: 0.1036
# Epoch 4/80
# 95/95 [==============================] - 0s 254us/sample - loss: 0.0726 - val_loss: 0.0635
# Epoch 5/80
# 95/95 [==============================] - 0s 218us/sample - loss: 0.0903 - val_loss: 0.0664
# Epoch 6/80
# 95/95 [==============================] - 0s 224us/sample - loss: 0.0417 - val_loss: 0.0482
# Epoch 7/80
# 95/95 [==============================] - 0s 268us/sample - loss: 0.0539 - val_loss: 0.0475
# Epoch 8/80
# 95/95 [==============================] - 0s 224us/sample - loss: 0.0326 - val_loss: 0.0337
# Epoch 9/80
# 95/95 [==============================] - 0s 268us/sample - loss: 0.0347 - val_loss: 0.0350
# Epoch 10/80
# 95/95 [==============================] - 0s 260us/sample - loss: 0.0253 - val_loss: 0.0299
# Epoch 11/80
# 95/95 [==============================] - 0s 224us/sample - loss: 0.0287 - val_loss: 0.0301
# Epoch 12/80
# 95/95 [==============================] - 0s 221us/sample - loss: 0.0239 - val_loss: 0.0284
# Epoch 13/80
# 95/95 [==============================] - 0s 253us/sample - loss: 0.0261 - val_loss: 0.0278
# Epoch 14/80
# 95/95 [==============================] - 0s 238us/sample - loss: 0.0224 - val_loss: 0.0273
# Epoch 15/80
# 95/95 [==============================] - 0s 236us/sample - loss: 0.0245 - val_loss: 0.0262
# Epoch 16/80
# 95/95 [==============================] - 0s 255us/sample - loss: 0.0218 - val_loss: 0.0273
# Epoch 17/80
# 95/95 [==============================] - 0s 242us/sample - loss: 0.0226 - val_loss: 0.0247
# Epoch 18/80
# 95/95 [==============================] - 0s 237us/sample - loss: 0.0204 - val_loss: 0.0244
# Epoch 19/80
# 95/95 [==============================] - 0s 256us/sample - loss: 0.0203 - val_loss: 0.0239
# Epoch 20/80
# 95/95 [==============================] - 0s 242us/sample - loss: 0.0198 - val_loss: 0.0237
# Epoch 21/80
# 95/95 [==============================] - 0s 309us/sample - loss: 0.0192 - val_loss: 0.0235
# Epoch 22/80
# 95/95 [==============================] - 0s 264us/sample - loss: 0.0194 - val_loss: 0.0230
# 95/95 [==============================] - 0s 243us/sample - loss: 0.0129 - val_loss: 0.0168
# Epoch 56/80
# 95/95 [==============================] - 0s 256us/sample - loss: 0.0129 - val_loss: 0.0172
# Epoch 57/80
# 95/95 [==============================] - 0s 288us/sample - loss: 0.0125 - val_loss: 0.0177
# Epoch 58/80
# 95/95 [==============================] - 0s 246us/sample - loss: 0.0119 - val_loss: 0.0166
# Epoch 59/80
# 95/95 [==============================] - 0s 273us/sample - loss: 0.0122 - val_loss: 0.0162
# Epoch 60/80
# 95/95 [==============================] - 0s 221us/sample - loss: 0.0122 - val_loss: 0.0163
# Epoch 61/80
# 95/95 [==============================] - 0s 279us/sample - loss: 0.0128 - val_loss: 0.0168
# Epoch 62/80
# 95/95 [==============================] - 0s 230us/sample - loss: 0.0121 - val_loss: 0.0166
# Epoch 63/80
# 95/95 [==============================] - 0s 252us/sample - loss: 0.0117 - val_loss: 0.0162
# Epoch 64/80
# 95/95 [==============================] - 0s 249us/sample - loss: 0.0122 - val_loss: 0.0160
# Epoch 65/80
# 95/95 [==============================] - 0s 250us/sample - loss: 0.0117 - val_loss: 0.0161
# Epoch 66/80
# 95/95 [==============================] - 0s 300us/sample - loss: 0.0115 - val_loss: 0.0166
# Epoch 67/80
# 95/95 [==============================] - 0s 272us/sample - loss: 0.0123 - val_loss: 0.0166
# Epoch 68/80
# 95/95 [==============================] - 0s 307us/sample - loss: 0.0121 - val_loss: 0.0160
# Epoch 69/80
# 95/95 [==============================] - 0s 311us/sample - loss: 0.0117 - val_loss: 0.0159
# Epoch 70/80
# 95/95 [==============================] - 0s 341us/sample - loss: 0.0127 - val_loss: 0.0160
# Epoch 71/80
# 95/95 [==============================] - 0s 270us/sample - loss: 0.0115 - val_loss: 0.0176
# Epoch 72/80
# 95/95 [==============================] - 0s 242us/sample - loss: 0.0116 - val_loss: 0.0167
# Epoch 73/80
# 95/95 [==============================] - 0s 233us/sample - loss: 0.0122 - val_loss: 0.0162
# Epoch 74/80
# 95/95 [==============================] - 0s 280us/sample - loss: 0.0130 - val_loss: 0.0168
# Epoch 75/80
# 95/95 [==============================] - 0s 247us/sample - loss: 0.0121 - val_loss: 0.0167
# Epoch 76/80
# 95/95 [==============================] - 0s 290us/sample - loss: 0.0123 - val_loss: 0.0160
# Epoch 77/80
# 95/95 [==============================] - 0s 234us/sample - loss: 0.0119 - val_loss: 0.0159
# Epoch 78/80
# 95/95 [==============================] - 0s 240us/sample - loss: 0.0120 - val_loss: 0.0161
# Epoch 79/80
# 95/95 [==============================] - 0s 225us/sample - loss: 0.0117 - val_loss: 0.0168
# Epoch 80/80
# 95/95 [==============================] - 0s 266us/sample - loss: 0.0134 - val_loss: 0.0170

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets

validation_target = Y[-N//2:]
validation_predictions = []

# index of first validation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1))[0,0] # 1x1 array -> scalar
  i += 1
  
  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# last train input
last_x = X[-N//2] # 1-D array of length T

while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, -1))[0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p)
  
  # make the new input
  last_x = np.roll(last_x, -1)
  last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
